# %% [markdown]
# # Population model
#
# Simple case:
# * $n(z)$ ~ SFR
# * Uniform luminosities $L = \int_{E_{\rm{min}}}^{10 E_{\rm{min}}} {\rm{d}}E \ E \frac{{\rm{d}N}}{{\rm{d}}E {\rm{d}}t }$

# %%
import numpy as np
import h5py
from matplotlib import pyplot as plt

# %% [markdown]
# ## Source population
#
# Start by randomly selecting source distances and positions to fill a universe with realistic sources.

# %%
from population_model import Population, SFR_evolution, power_density
# Out:
# /Users/fran/projects/bayes/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
Emin = 100 # TeV
alpha = 2.0
N0 = 1.0E-9 # Mpc^-3
L = 1.0E+45 # TeV s^-1

# %%
# Create a population
population = Population(N0, SFR_evolution, L, Emin, alpha, zmin=0, zmax=6)

# %%
# Plot
population.show_redshift_dist();

# %%
population.show()

# %%
# Save to HDF5 file for use elsewhere 
population.to_file('test.h5')
